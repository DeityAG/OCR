# %%
# !pip install torch==2.0.1
# !pip install torchvision==0.15.2
# !pip install transformers==4.37.2
# !pip install tiktoken==0.6.0
# !pip install verovio==4.3.1
# !pip install accelerate==0.28.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 87.7 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 70.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 39.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 3.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 10.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 15.1 MB/s eta 0:00:0000:010:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 9.1 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !pip install verovio
# !pip install tiktoken
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 63.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 20.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install --upgrade transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 55.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 70.1 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.37.2
#     Uninstalling transformers-4.37.2:
#       Successfully uninstalled transformers-4.37.2
# ...

# %% [markdown]
# ## Raw GOT only implementation:

# %%
import torch
from transformers import AutoModel, AutoTokenizer

def load_model():
    # Load the GOT model and tokenizer
    tokenizer = AutoTokenizer.from_pretrained('stepfun-ai/GOT-OCR2_0', trust_remote_code=True)
    model = AutoModel.from_pretrained('stepfun-ai/GOT-OCR2_0', trust_remote_code=True, low_cpu_mem_usage=True, device_map='cuda', use_safetensors=True, pad_token_id=tokenizer.eos_token_id)
    model = model.eval().cuda()
    return model, tokenizer

def perform_ocr(image_path, model, tokenizer, ocr_type='ocr'):
    try:
        res = model.chat(tokenizer, image_path, ocr_type=ocr_type)
        return res
    except Exception as e:
        print(f"Error during OCR: {e}")
        return "OCR processing failed. Please check the model requirements and input format."

def verify_hindi_english(text):
    hindi_range = range(0x0900, 0x097F)
    english_range = range(0x0041, 0x007A)

    has_hindi = any(ord(char) in hindi_range for char in text)
    has_english = any(ord(char) in english_range for char in text)

    if has_hindi and has_english:
        print("The extracted text contains both Hindi and English characters.")
    elif has_hindi:
        print("The extracted text contains only Hindi characters.")
    elif has_english:
        print("The extracted text contains only English characters.")
    else:
        print("The extracted text does not contain Hindi or English characters.")

if __name__ == "__main__":
    model, tokenizer = load_model()
    image_path = "/kaggle/input/ocr-dataset/eng1.jpg"
    extracted_text = perform_ocr(image_path, model, tokenizer)
    print("Extracted text:")
    print(extracted_text)
    verify_hindi_english(extracted_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Extracted text:
# *  Dreams Hold fast to dreams For if dreams die Life is a broken- winged bird That cannot fly.  Hold fast to dreams For when dreams go Life is a barren field Frozen with snow.  - Langston Hughes e lif notes www. e lif notes. com
# The extracted text contains only English characters.

# %% [markdown]
# ### Raw GOT for hindi text extraction:

# %%
def verify_hindi_english(text):
    hindi_range = range(0x0900, 0x097F)
    english_range = range(0x0041, 0x007A)

    has_hindi = any(ord(char) in hindi_range for char in text)
    has_english = any(ord(char) in english_range for char in text)

    if has_hindi and has_english:
        print("The extracted text contains both Hindi and English characters.")
    elif has_hindi:
        print("The extracted text contains only Hindi characters.")
    elif has_english:
        print("The extracted text contains only English characters.")
    else:
        print("The extracted text does not contain Hindi or English characters.")

if __name__ == "__main__":
    model, tokenizer = load_model()
    image_path = "/kaggle/input/ocr-dataset/hin2.jpg"
    extracted_text = perform_ocr(image_path, model, tokenizer)
    print("Extracted text:")
    print(extracted_text)
    verify_hindi_english(extracted_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Extracted text:
# 11111
# The extracted text does not contain Hindi or English characters.

# %% [markdown]
# ### By just using GOT for hindi txt extraction, the generations are not hindi texts.

# %% [markdown]
# ## **Implimention GOT with Easy OCR:**

# %%
# !pip install easyocr
# !pip install easyocr opencv-python-headless langdetect

# %%
import cv2
import numpy as np
import easyocr
import re
import torch
from transformers import AutoModel, AutoTokenizer
from langdetect import detect_langs

def load_got_model():
    # Load the GOT-OCR2_0 model and tokenizer
    tokenizer = AutoTokenizer.from_pretrained('stepfun-ai/GOT-OCR2_0', trust_remote_code=True)
    model = AutoModel.from_pretrained('stepfun-ai/GOT-OCR2_0', trust_remote_code=True, low_cpu_mem_usage=True, device_map='cuda', use_safetensors=True, pad_token_id=tokenizer.eos_token_id)
    model.eval().cuda()
    return model, tokenizer

def load_easyocr_reader():
    
    reader = easyocr.Reader(['hi', 'en'], gpu=False)  
    return reader

def preprocess_image(image_path):
    img = cv2.imread(image_path)
    
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    denoised = cv2.fastNlMeansDenoising(gray, None, 10, 7, 21)
    
    thresh = cv2.adaptiveThreshold(denoised, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
    
    kernel = np.ones((1, 1), np.uint8)
    dilated = cv2.dilate(thresh, kernel, iterations=1)
    
    return dilated

def perform_got_ocr(image_path, model, tokenizer, ocr_type='ocr'):
    try:
        res = model.chat(tokenizer, image_path, ocr_type=ocr_type)
        return res
    except Exception as e:
        print(f"Error during GOT OCR: {e}")
        return None

def perform_easyocr(image_path, reader):
    
    preprocessed_image = preprocess_image(image_path)
    
    # Perform OCR with EasyOCR
    results = reader.readtext(preprocessed_image, paragraph=True, detail=0, 
                               contrast_ths=0.2, adjust_contrast=0.5, 
                               add_margin=0.1, width_ths=0.7, height_ths=0.7)
    
    
    extracted_text = ' '.join(results)
    
    return extracted_text

def detect_languages(text):
    # Remove non-alphabetic characters and extra spaces
    cleaned_text = re.sub(r'[^a-zA-Z\u0900-\u097F\s]', '', text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    
    if not cleaned_text:
        return []

    try:
        # Detect languages
        langs = detect_langs(cleaned_text)
        
        # Filter and format results
        detected = []
        for lang in langs:
            if lang.lang == 'hi' and lang.prob > 0.1:
                detected.append('Hindi')
            elif lang.lang == 'en' and lang.prob > 0.1:
                detected.append('English')
        
        return detected
    except:
        # If language detection fails, fall back to character range check
        return fallback_language_check(cleaned_text)

def fallback_language_check(text):
    hindi_range = range(0x0900, 0x097F)
    english_range = range(0x0041, 0x007A)
    
    has_hindi = any(ord(char) in hindi_range for char in text)
    has_english = any(ord(char) in english_range for char in text)
    
    detected = []
    if has_hindi:
        detected.append('Hindi')
    if has_english:
        detected.append('English')
    
    return detected

if __name__ == "__main__":
    image_path = "/kaggle/input/ocr-dataset/hin2.jpg"
    
    # Load models
    got_model, tokenizer = load_got_model()
    easyocr_reader = load_easyocr_reader()
    
    # Perform OCR using the GOT model
    extracted_text = perform_got_ocr(image_path, got_model, tokenizer)
    
    # If the extracted text does contain Hindi characters, use EasyOCR
    if not extracted_text or not any('\u0900' <= char <= '\u097F' for char in extracted_text):
        print("Falling back to EasyOCR for Hindi text extraction.")
        extracted_text = perform_easyocr(image_path, easyocr_reader)
    
    print("Extracted text:")
    print(extracted_text)
    
    languages_detected = detect_languages(extracted_text)
    if languages_detected:
        print("Detected languages:", ', '.join(languages_detected))
    else:
        print("No languages detected.")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Falling back to EasyOCR for Hindi text extraction.
# Extracted text:
# जमीन ऐ चल ~ सका " आसमानसे॰सषषगया कट केरपरथची  परिंदा षडन थी तc1@ करपई रर एटट मकाननकी ख्वाई9 वों अपने वट केसकच्चे मकान से मख पराईंपआग P तोच्या mic उसे बच स m07 औ़र  अपनी
# Detected languages: Hindi
